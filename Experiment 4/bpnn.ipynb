# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess data
x_train = x_train.reshape(-1, 784).astype(np.float32) / 255.0
x_test = x_test.reshape(-1, 784).astype(np.float32) / 255.0
y_train = tf.one_hot(y_train, depth=10)
y_test = tf.one_hot(y_test, depth=10)

# Hyperparameter combinations
hidden_layer_configs = [(160, 100), (100, 100), (100, 160), (60, 60), (100, 60)]
learning_rates = [0.01, 0.1, 1.0]
num_epochs = 20
batch_size = 10
n_input = 784
n_output = 10

# Iterate over different configurations
for (n_hidden1, n_hidden2) in hidden_layer_configs:
    for learning_rate in learning_rates:
        print(f"\nTraining with Hidden Layers: ({n_hidden1}, {n_hidden2}), Learning Rate: {learning_rate}")

        # Initialize weights and biases
        initializer = tf.initializers.GlorotUniform()
        W1 = tf.Variable(initializer([n_input, n_hidden1]))
        b1 = tf.Variable(tf.zeros([n_hidden1]))
        W2 = tf.Variable(initializer([n_hidden1, n_hidden2]))
        b2 = tf.Variable(tf.zeros([n_hidden2]))
        W3 = tf.Variable(initializer([n_hidden2, n_output]))
        b3 = tf.Variable(tf.zeros([n_output]))

        # Define forward pass
        def forward_pass(x):
            z1 = tf.add(tf.matmul(x, W1), b1)
            a1 = tf.nn.relu(z1)
            z2 = tf.add(tf.matmul(a1, W2), b2)
            a2 = tf.nn.relu(z2)
            logits = tf.add(tf.matmul(a2, W3), b3)
            return logits

        # Loss function
        def compute_loss(logits, labels):
            return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits))

        # Accuracy metric
        def compute_accuracy(logits, labels):
            correct_preds = tf.equal(tf.argmax(logits, axis=1), tf.argmax(labels, axis=1))
            return tf.reduce_mean(tf.cast(correct_preds, tf.float32))

        # Optimizer
        optimizer = tf.optimizers.SGD(learning_rate)

        # Training loop
        train_losses, test_accuracies = [], []
        start_time = time.time()
        for epoch in range(num_epochs):
            for i in range(0, x_train.shape[0], batch_size):
                x_batch = x_train[i:i + batch_size]
                y_batch = y_train[i:i + batch_size]

                with tf.GradientTape() as tape:
                    logits = forward_pass(x_batch)
                    loss = compute_loss(logits, y_batch)

                gradients = tape.gradient(loss, [W1, b1, W2, b2, W3, b3])
                optimizer.apply_gradients(zip(gradients, [W1, b1, W2, b2, W3, b3]))

            # Evaluate after each epoch
            test_logits = forward_pass(x_test)
            test_accuracy = compute_accuracy(test_logits, y_test)
            train_losses.append(loss.numpy())
            test_accuracies.append(test_accuracy.numpy())
            print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {loss.numpy():.4f}, Test Accuracy: {test_accuracy.numpy():.4f}")

        # Calculate execution time
        execution_time = time.time() - start_time
        print(f"Execution Time: {execution_time:.2f} seconds")

        # Plot loss and accuracy curves
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.plot(range(1, num_epochs + 1), train_losses, marker='o', label='Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Loss Curve (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(range(1, num_epochs + 1), test_accuracies, marker='o', color='r', label='Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title(f'Accuracy Curve (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.legend()
        plt.show()

        # Confusion matrix
        y_pred = tf.argmax(forward_pass(x_test), axis=1).numpy()
        y_true = tf.argmax(y_test, axis=1).numpy()
        conf_matrix = confusion_matrix(y_true, y_pred)

        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title(f'Confusion Matrix (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.show()

        print("============================================")
# Out:
# Training with Hidden Layers: (160, 100), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0472, Test Accuracy: 0.9327
# Epoch 2/20, Loss: 0.0256, Test Accuracy: 0.9532
# Epoch 3/20, Loss: 0.0158, Test Accuracy: 0.9616
# Epoch 4/20, Loss: 0.0110, Test Accuracy: 0.9677
# Epoch 5/20, Loss: 0.0081, Test Accuracy: 0.9713
# Epoch 6/20, Loss: 0.0064, Test Accuracy: 0.9726
# Epoch 7/20, Loss: 0.0048, Test Accuracy: 0.9742
# Epoch 8/20, Loss: 0.0035, Test Accuracy: 0.9753
# Epoch 9/20, Loss: 0.0029, Test Accuracy: 0.9759
# Epoch 10/20, Loss: 0.0024, Test Accuracy: 0.9760
# Epoch 11/20, Loss: 0.0020, Test Accuracy: 0.9762
# Epoch 12/20, Loss: 0.0017, Test Accuracy: 0.9771
# Epoch 13/20, Loss: 0.0015, Test Accuracy: 0.9770
# Epoch 14/20, Loss: 0.0012, Test Accuracy: 0.9769
# Epoch 15/20, Loss: 0.0012, Test Accuracy: 0.9770
# Epoch 16/20, Loss: 0.0010, Test Accuracy: 0.9778
# Epoch 17/20, Loss: 0.0009, Test Accuracy: 0.9779
# Epoch 18/20, Loss: 0.0007, Test Accuracy: 0.9778
# Epoch 19/20, Loss: 0.0007, Test Accuracy: 0.9781
# Epoch 20/20, Loss: 0.0007, Test Accuracy: 0.9777
# Execution Time: 2110.26 seconds
# ============================================
#
# Training with Hidden Layers: (160, 100), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0038, Test Accuracy: 0.9580
# Epoch 2/20, Loss: 0.0010, Test Accuracy: 0.9619
# Epoch 3/20, Loss: 0.0007, Test Accuracy: 0.9716
# Epoch 4/20, Loss: 0.0008, Test Accuracy: 0.9732
# Epoch 5/20, Loss: 0.0012, Test Accuracy: 0.9733
# Epoch 6/20, Loss: 0.0001, Test Accuracy: 0.9712
# Epoch 7/20, Loss: 0.0000, Test Accuracy: 0.9742
# Epoch 8/20, Loss: 0.0000, Test Accuracy: 0.9720
# Epoch 9/20, Loss: 0.0004, Test Accuracy: 0.9739
# Epoch 10/20, Loss: 0.0019, Test Accuracy: 0.9689
# Epoch 11/20, Loss: 0.0014, Test Accuracy: 0.9728
# Epoch 12/20, Loss: 0.0000, Test Accuracy: 0.9756
# Epoch 13/20, Loss: 0.0001, Test Accuracy: 0.9749
# Epoch 14/20, Loss: 0.0002, Test Accuracy: 0.9782
# Epoch 15/20, Loss: 0.0000, Test Accuracy: 0.9759
# Epoch 16/20, Loss: 0.0000, Test Accuracy: 0.9692
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9773
# Epoch 18/20, Loss: 0.0000, Test Accuracy: 0.9696
# Epoch 19/20, Loss: 0.0000, Test Accuracy: 0.9767
# Epoch 20/20, Loss: 0.0002, Test Accuracy: 0.9771
# Execution Time: 2070.55 seconds
# ============================================
#
# Training with Hidden Layers: (160, 100), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.0966, Test Accuracy: 0.2110
# Epoch 2/20, Loss: 2.0692, Test Accuracy: 0.1698
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 2066.57 seconds
# ============================================
#
# Training with Hidden Layers: (100, 100), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0619, Test Accuracy: 0.9303
# Epoch 2/20, Loss: 0.0387, Test Accuracy: 0.9492
# Epoch 3/20, Loss: 0.0272, Test Accuracy: 0.9586
# Epoch 4/20, Loss: 0.0210, Test Accuracy: 0.9649
# Epoch 5/20, Loss: 0.0165, Test Accuracy: 0.9675
# Epoch 6/20, Loss: 0.0117, Test Accuracy: 0.9709
# Epoch 7/20, Loss: 0.0086, Test Accuracy: 0.9721
# Epoch 8/20, Loss: 0.0060, Test Accuracy: 0.9738
# Epoch 9/20, Loss: 0.0045, Test Accuracy: 0.9741
# Epoch 10/20, Loss: 0.0036, Test Accuracy: 0.9743
# Epoch 11/20, Loss: 0.0028, Test Accuracy: 0.9739
# Epoch 12/20, Loss: 0.0023, Test Accuracy: 0.9738
# Epoch 13/20, Loss: 0.0019, Test Accuracy: 0.9748
# Epoch 14/20, Loss: 0.0016, Test Accuracy: 0.9754
# Epoch 15/20, Loss: 0.0014, Test Accuracy: 0.9756
# Epoch 16/20, Loss: 0.0012, Test Accuracy: 0.9760
# Epoch 17/20, Loss: 0.0011, Test Accuracy: 0.9763
# Epoch 18/20, Loss: 0.0009, Test Accuracy: 0.9765
# Epoch 19/20, Loss: 0.0009, Test Accuracy: 0.9763
# Epoch 20/20, Loss: 0.0007, Test Accuracy: 0.9765
# Execution Time: 1982.69 seconds
# ============================================
#
# Training with Hidden Layers: (100, 100), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0032, Test Accuracy: 0.9520
# Epoch 2/20, Loss: 0.0011, Test Accuracy: 0.9619
# Epoch 3/20, Loss: 0.0038, Test Accuracy: 0.9691
# Epoch 4/20, Loss: 0.0016, Test Accuracy: 0.9686
# Epoch 5/20, Loss: 0.0022, Test Accuracy: 0.9704
# Epoch 6/20, Loss: 0.0006, Test Accuracy: 0.9671
# Epoch 7/20, Loss: 0.0022, Test Accuracy: 0.9679
# Epoch 8/20, Loss: 0.0000, Test Accuracy: 0.9726
# Epoch 9/20, Loss: 0.0001, Test Accuracy: 0.9682
# Epoch 10/20, Loss: 0.0001, Test Accuracy: 0.9692
# Epoch 11/20, Loss: 0.0007, Test Accuracy: 0.9689
# Epoch 12/20, Loss: 0.0002, Test Accuracy: 0.9737
# Epoch 13/20, Loss: 0.0004, Test Accuracy: 0.9719
# Epoch 14/20, Loss: 0.0014, Test Accuracy: 0.9725
# Epoch 15/20, Loss: 0.0000, Test Accuracy: 0.9671
# Epoch 16/20, Loss: 0.0006, Test Accuracy: 0.9736
# Epoch 17/20, Loss: 0.0090, Test Accuracy: 0.9748
# Epoch 18/20, Loss: 0.0001, Test Accuracy: 0.9758
# Epoch 19/20, Loss: 0.0006, Test Accuracy: 0.9727
# Epoch 20/20, Loss: 0.0000, Test Accuracy: 0.9716
# Execution Time: 1976.98 seconds
# ============================================
#
# Training with Hidden Layers: (100, 100), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1961.56 seconds
# ============================================
#
# Training with Hidden Layers: (100, 160), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0573, Test Accuracy: 0.9261
# Epoch 2/20, Loss: 0.0319, Test Accuracy: 0.9463
# Epoch 3/20, Loss: 0.0209, Test Accuracy: 0.9576
# Epoch 4/20, Loss: 0.0135, Test Accuracy: 0.9612
# Epoch 5/20, Loss: 0.0095, Test Accuracy: 0.9647
# Epoch 6/20, Loss: 0.0074, Test Accuracy: 0.9677
# Epoch 7/20, Loss: 0.0055, Test Accuracy: 0.9703
# Epoch 8/20, Loss: 0.0042, Test Accuracy: 0.9708
# Epoch 9/20, Loss: 0.0033, Test Accuracy: 0.9713
# Epoch 10/20, Loss: 0.0026, Test Accuracy: 0.9721
# Epoch 11/20, Loss: 0.0021, Test Accuracy: 0.9724
# Epoch 12/20, Loss: 0.0018, Test Accuracy: 0.9728
# Epoch 13/20, Loss: 0.0015, Test Accuracy: 0.9736
# Epoch 14/20, Loss: 0.0013, Test Accuracy: 0.9743
# Epoch 15/20, Loss: 0.0011, Test Accuracy: 0.9756
# Epoch 16/20, Loss: 0.0010, Test Accuracy: 0.9766
# Epoch 17/20, Loss: 0.0009, Test Accuracy: 0.9764
# Epoch 18/20, Loss: 0.0007, Test Accuracy: 0.9766
# Epoch 19/20, Loss: 0.0006, Test Accuracy: 0.9769
# Epoch 20/20, Loss: 0.0006, Test Accuracy: 0.9773
# Execution Time: 1976.77 seconds
# ============================================
#
# Training with Hidden Layers: (100, 160), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0075, Test Accuracy: 0.9505
# Epoch 2/20, Loss: 0.0018, Test Accuracy: 0.9650
# Epoch 3/20, Loss: 0.0002, Test Accuracy: 0.9699
# Epoch 4/20, Loss: 0.0003, Test Accuracy: 0.9737
# Epoch 5/20, Loss: 0.0019, Test Accuracy: 0.9718
# Epoch 6/20, Loss: 0.0002, Test Accuracy: 0.9718
# Epoch 7/20, Loss: 0.0001, Test Accuracy: 0.9701
# Epoch 8/20, Loss: 0.0004, Test Accuracy: 0.9719
# Epoch 9/20, Loss: 0.0001, Test Accuracy: 0.9697
# Epoch 10/20, Loss: 0.0000, Test Accuracy: 0.9759
# Epoch 11/20, Loss: 0.0000, Test Accuracy: 0.9779
# Epoch 12/20, Loss: 0.0000, Test Accuracy: 0.9773
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9722
# Epoch 14/20, Loss: 0.0000, Test Accuracy: 0.9754
# Epoch 15/20, Loss: 0.0000, Test Accuracy: 0.9795
# Epoch 16/20, Loss: 0.0000, Test Accuracy: 0.9791
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9800
# Epoch 18/20, Loss: 0.0001, Test Accuracy: 0.9790
# Epoch 19/20, Loss: 0.0010, Test Accuracy: 0.9783
# Epoch 20/20, Loss: 0.0000, Test Accuracy: 0.9676
# Execution Time: 1978.28 seconds
# ============================================
#
# Training with Hidden Layers: (100, 160), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.1571, Test Accuracy: 0.2032
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1990.86 seconds
# ============================================
#
# Training with Hidden Layers: (60, 60), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0626, Test Accuracy: 0.9241
# Epoch 2/20, Loss: 0.0337, Test Accuracy: 0.9446
# Epoch 3/20, Loss: 0.0228, Test Accuracy: 0.9536
# Epoch 4/20, Loss: 0.0195, Test Accuracy: 0.9589
# Epoch 5/20, Loss: 0.0156, Test Accuracy: 0.9634
# Epoch 6/20, Loss: 0.0125, Test Accuracy: 0.9660
# Epoch 7/20, Loss: 0.0102, Test Accuracy: 0.9679
# Epoch 8/20, Loss: 0.0085, Test Accuracy: 0.9690
# Epoch 9/20, Loss: 0.0074, Test Accuracy: 0.9707
# Epoch 10/20, Loss: 0.0062, Test Accuracy: 0.9713
# Epoch 11/20, Loss: 0.0049, Test Accuracy: 0.9721
# Epoch 12/20, Loss: 0.0040, Test Accuracy: 0.9726
# Epoch 13/20, Loss: 0.0033, Test Accuracy: 0.9725
# Epoch 14/20, Loss: 0.0027, Test Accuracy: 0.9729
# Epoch 15/20, Loss: 0.0024, Test Accuracy: 0.9734
# Epoch 16/20, Loss: 0.0019, Test Accuracy: 0.9740
# Epoch 17/20, Loss: 0.0016, Test Accuracy: 0.9742
# Epoch 18/20, Loss: 0.0013, Test Accuracy: 0.9750
# Epoch 19/20, Loss: 0.0012, Test Accuracy: 0.9754
# Epoch 20/20, Loss: 0.0010, Test Accuracy: 0.9754
# Execution Time: 1946.80 seconds
# ============================================
#
# Training with Hidden Layers: (60, 60), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0043, Test Accuracy: 0.9548
# Epoch 2/20, Loss: 0.0015, Test Accuracy: 0.9568
# Epoch 3/20, Loss: 0.0032, Test Accuracy: 0.9622
# Epoch 4/20, Loss: 0.0010, Test Accuracy: 0.9674
# Epoch 5/20, Loss: 0.0003, Test Accuracy: 0.9675
# Epoch 6/20, Loss: 0.0002, Test Accuracy: 0.9665
# Epoch 7/20, Loss: 0.0003, Test Accuracy: 0.9617
# Epoch 8/20, Loss: 0.0001, Test Accuracy: 0.9632
# Epoch 9/20, Loss: 0.0004, Test Accuracy: 0.9683
# Epoch 10/20, Loss: 0.0000, Test Accuracy: 0.9694
# Epoch 11/20, Loss: 0.0000, Test Accuracy: 0.9680
# Epoch 12/20, Loss: 0.0000, Test Accuracy: 0.9714
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9654
# Epoch 14/20, Loss: 0.0000, Test Accuracy: 0.9615
# Epoch 15/20, Loss: 0.0002, Test Accuracy: 0.9673
# Epoch 16/20, Loss: 0.0000, Test Accuracy: 0.9617
# Epoch 17/20, Loss: 0.0000, Test Accuracy: 0.9715
# Epoch 18/20, Loss: 0.0000, Test Accuracy: 0.9721
# Epoch 19/20, Loss: 0.0000, Test Accuracy: 0.9731
# Epoch 20/20, Loss: 0.0002, Test Accuracy: 0.9698
# Execution Time: 1932.05 seconds
# ============================================
#
# Training with Hidden Layers: (60, 60), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.0407, Test Accuracy: 0.2023
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1927.22 seconds
# ============================================
#
# Training with Hidden Layers: (100, 60), Learning Rate: 0.01
# Epoch 1/20, Loss: 0.0556, Test Accuracy: 0.9276
# Epoch 2/20, Loss: 0.0334, Test Accuracy: 0.9476
# Epoch 3/20, Loss: 0.0231, Test Accuracy: 0.9564
# Epoch 4/20, Loss: 0.0172, Test Accuracy: 0.9615
# Epoch 5/20, Loss: 0.0138, Test Accuracy: 0.9670
# Epoch 6/20, Loss: 0.0108, Test Accuracy: 0.9678
# Epoch 7/20, Loss: 0.0091, Test Accuracy: 0.9697
# Epoch 8/20, Loss: 0.0070, Test Accuracy: 0.9705
# Epoch 9/20, Loss: 0.0057, Test Accuracy: 0.9712
# Epoch 10/20, Loss: 0.0046, Test Accuracy: 0.9713
# Epoch 11/20, Loss: 0.0038, Test Accuracy: 0.9717
# Epoch 12/20, Loss: 0.0031, Test Accuracy: 0.9726
# Epoch 13/20, Loss: 0.0026, Test Accuracy: 0.9730
# Epoch 14/20, Loss: 0.0022, Test Accuracy: 0.9730
# Epoch 15/20, Loss: 0.0019, Test Accuracy: 0.9744
# Epoch 16/20, Loss: 0.0017, Test Accuracy: 0.9735
# Epoch 17/20, Loss: 0.0014, Test Accuracy: 0.9745
# Epoch 18/20, Loss: 0.0014, Test Accuracy: 0.9748
# Epoch 19/20, Loss: 0.0012, Test Accuracy: 0.9753
# Epoch 20/20, Loss: 0.0011, Test Accuracy: 0.9756
# Execution Time: 1937.60 seconds
# ============================================
#
# Training with Hidden Layers: (100, 60), Learning Rate: 0.1
# Epoch 1/20, Loss: 0.0073, Test Accuracy: 0.9557
# Epoch 2/20, Loss: 0.0026, Test Accuracy: 0.9652
# Epoch 3/20, Loss: 0.0003, Test Accuracy: 0.9663
# Epoch 4/20, Loss: 0.0006, Test Accuracy: 0.9672
# Epoch 5/20, Loss: 0.0004, Test Accuracy: 0.9662
# Epoch 6/20, Loss: 0.0026, Test Accuracy: 0.9657
# Epoch 7/20, Loss: 0.0001, Test Accuracy: 0.9693
# Epoch 8/20, Loss: 0.0001, Test Accuracy: 0.9701
# Epoch 9/20, Loss: 0.0000, Test Accuracy: 0.9699
# Epoch 10/20, Loss: 0.0031, Test Accuracy: 0.9743
# Epoch 11/20, Loss: 0.0001, Test Accuracy: 0.9723
# Epoch 12/20, Loss: 0.0000, Test Accuracy: 0.9681
# Epoch 13/20, Loss: 0.0000, Test Accuracy: 0.9706
# Epoch 14/20, Loss: 0.0000, Test Accuracy: 0.9726
# Epoch 15/20, Loss: 0.0000, Test Accuracy: 0.9689
# Epoch 16/20, Loss: 0.0002, Test Accuracy: 0.9706
# Epoch 17/20, Loss: 0.0001, Test Accuracy: 0.9726
# Epoch 18/20, Loss: 0.0000, Test Accuracy: 0.9699
# Epoch 19/20, Loss: 0.0000, Test Accuracy: 0.9735
# Epoch 20/20, Loss: 0.0000, Test Accuracy: 0.9654
# Execution Time: 1958.92 seconds
# ============================================
#
# Training with Hidden Layers: (100, 60), Learning Rate: 1.0
# Epoch 1/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 2/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 3/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 4/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 5/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 6/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 7/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 8/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 9/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 10/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 11/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 12/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 13/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 14/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 15/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 16/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 17/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 18/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 19/20, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch 20/20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1963.24 seconds
# ============================================
